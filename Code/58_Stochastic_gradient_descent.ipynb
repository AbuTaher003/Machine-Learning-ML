# %% [markdown]
# - ``` Ekhane amra 3 bar Regression korbo.```
#    ```1. fist time LinearRegression use kore predict korbo.```
#    ```2. nije ekta stochastic regression er class banabo, seta diye korbo.```
#    ```3. SGDRegressor use kore abar predict korbo.```

# %%
from sklearn.datasets import load_diabetes

import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
import time

# %%
X,y = load_diabetes(return_X_y=True)

# %%
print(X.shape)
print(y.shape)
# Out:
# (442, 10)
# (442,)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
reg = LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(reg.coef_)
print(reg.intercept_)
# Out:
# [  -9.15865318 -205.45432163  516.69374454  340.61999905 -895.5520019
#   561.22067904  153.89310954  126.73139688  861.12700152   52.42112238]
# 151.88331005254167

# %%
y_pred = reg.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.439933866156897

# %%
class MY_SGDRegressor:
    
    def __init__(self, learning_rate = 0.1, epochs = 100):
        self.coef_ = None
        self.intercept_ = None
        self.lr = learning_rate
        self.epochs = epochs

    def fit(self, X_train, y_train):
        pass
        # init your coefs
        self.intercept_ = 0
        self.coef_ = np.ones(X_train.shape[1])
        

        for i in range(self.epochs):
            for j in range(X_train.shape[0]):
                
                idx = np.random.randint(0,X_train.shape[0])
                
                y_hat = self.intercept_ + np.dot(X_train[idx],self.coef_)
                
                slope_int = -2 * (y_train[idx] - y_hat)
                self.intercept_ = self.intercept_ - self.lr * slope_int
                
                slope_coef = -2 * np.dot((y_train[idx] - y_hat), X_train[idx])
                self.coef_ = self.coef_ - self.lr * slope_coef

        print(self.intercept_ , self.coef_)
        
    def predict(self, X_test):
        return self.intercept_ + np.dot(X_test,self.coef_)

# %%
sgd = MY_SGDRegressor(learning_rate=0.01,epochs=50)

# %%
sgd.fit(X_train,y_train)
# Out:
# 159.53047496846185 [  60.65760533  -67.28176679  346.57647684  251.14214774   21.42499705
#   -21.49394832 -175.50391952  132.62222375  318.98733701  120.0268529 ]

# %%
y_pred = sgd.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.4219384870258409

# %%
# using SGDRegressor()

from sklearn.linear_model import SGDRegressor

# %%
reg = SGDRegressor(max_iter = 100, learning_rate = 'constant', eta0 = 0.01)

# %%
reg.fit(X_train,y_train)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_stochastic_gradient.py:1616: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# SGDRegressor(learning_rate='constant', max_iter=100)

# %%
y_pred = reg.predict(X_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.43277420592683435
